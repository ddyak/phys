# %%
import sys, ROOT
from ROOT import gRandom, TCanvas, TFormula, TF1,TF2, TH1F, TH2F, TStopwatch
from tqdm import tqdm_notebook as tqdm
import numpy as np

ax = 0
bx = 0.7
ay = 2
by = 3
expect = 7.4523

def f(x, p): return np.exp(x[0]+x[1])/(1+x[1]*np.sqrt(x[0])/2)
# Out:
# Welcome to JupyROOT 6.16/00

# %%
h2 = TH2F('h2', 'histogram tytle', 100, 0, 0.7, 100, 2, 3);
for i in range(100):
    for j in range(100):
        for _ in range(int(f([0.001+0.7*i/100.0, 2.0+j/100.0],[]))):
            h2.Fill(0.001+0.7*i/100.0, 2+j/100.0);

c = ROOT.TCanvas("myCanvasName","The Canvas Title", 1200, 500)
h2.Draw('lego')
c.Draw();
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName

# %%
c = ROOT.TCanvas("myCanvasName","The Canvas Title", 1200, 500)
ff = TF2("ff2", f, 0.00, 0.7, 2, 3, 1)
ff.SetNpx(100)
ff.Draw("colz")
c.Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName

# %%
N_ = 10000
temp = 1000

integral = 0
std = 0
cur = 0
cur_std = 0
arr = np.zeros(N)

print('N,      integral,             std,                 current,      current std')
for N in range (1, N_+1):
    if (N%temp==0):
        std = np.sqrt((np.mean(arr[:N]**2)-np.mean(arr[:N])**2)/N)
        cur_std = np.sqrt((np.mean(arr[N-temp:N]**2)-np.mean(arr[N-temp:N])**2)/temp)
        print(N, integral/N, std, cur/temp, cur_std)
        cur = 0
        
    sample_x = gRandom.Uniform(ax, bx)
    sample_y = gRandom.Uniform(ay, by)
    sample = (bx-ax)*(by-ay)*f([sample_x, sample_y], 0)
    integral += sample
    cur += sample
    arr[N-1] = f([sample_x, sample_y], 0)*((bx-ax)*(by-ay))
# Out:
# N,      integral,             std,                 current,      current std
# (1000, 7.441496395981947, 0.060296073701552565, 7.441496395981947, 0.060296073701552565)
# (2000, 7.40415067792893, 0.04173604310011205, 7.366804959875915, 0.05815357388042073)
# (3000, 7.409573547854348, 0.03418475223190603, 7.4204192877051955, 0.06003840288806317)
# (4000, 7.426463710851863, 0.029623714464806904, 7.477134199844415, 0.05979890646537762)
# (5000, 7.430543264328785, 0.02639715233316003, 7.446861478236446, 0.05851741531983445)
# (6000, 7.4326481690222606, 0.024063017667618033, 7.4431726924896395, 0.05898162789266669)
# (7000, 7.445299771902088, 0.02236925955815467, 7.521209389181114, 0.06097955175311088)
# (8000, 7.444084688746429, 0.020966752241314935, 7.435579106656769, 0.06058308409468999)
# (9000, 7.455720359160439, 0.019764455458548408, 7.548805722472542, 0.05953795044526513)
# (10000, 7.4524543306919036, 0.01874906093563614, 7.42306007447505, 0.05969308485660366)
